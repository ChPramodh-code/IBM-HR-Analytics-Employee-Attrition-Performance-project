# %% [markdown]
# Project Title: IBMHRAnalyticsEmployeeAttrition&Performance.

# %% [markdown]
# Data Loading and Data pre-processing:

# %%
# importing the requried libraries:
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
# Dataset Loading Using the Pandas:
dataset= pd.read_csv(r"c:\Users\pramodh\OneDrive\Desktop\HR-Employee-Attrition.csv")
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# checking for the null values in the data:
dataset.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There is no missing values in the dataset.

# %%
# checking for the Duplicate values in the data:
print(f"The duplicate data in dataset: {dataset.duplicated().sum()}")
# Out:
# The duplicate data in dataset: 0

# %% [markdown]
# There is no duplicate values or entries in the dataset.

# %%
dataset.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Data Analysis:

# %% [markdown]
# Data Analysis:

# %%
# The Graph of Employees in IBM in different Age Groups:
ax = sb.histplot(data=dataset, x='Age',kde = True)
ax.set_title("Distribution of employees as per Age")
ax.set(xlabel="Age")
ax.set(ylabel="count of employees at the age group")
# Out:
# [Text(0, 0.5, 'count of employees at the age group')]

# %%
# The Graph Of Male VS Female Employees working in IBM:
ab=sb.countplot(data = dataset,x='Gender')
ab.set_title("Count of Employees in Male and Female Gender")
ab.set(xlabel="gender")
ab.set(ylabel="Count of employees")
# Out:
# [Text(0, 0.5, 'Count of employees')]

# %%
a=dataset['Gender']
male_count = 0
female_count = 0
for i in a:
    if i == 'Male':
        male_count = male_count + 1
    if i == 'Female':
        female_count = female_count + 1
if female_count > male_count:
    print(f"female employees is greater than male employees with difference of {female_count-male_count} ")
else:
    print(f"male employees is greater than female employees with difference of {male_count-female_count} ")
# Out:
# male employees is greater than female employees with difference of 294

# %%
# The Graph Of Employees in different departments in IBM:
ac=sb.countplot(data = dataset,x='Department')
ac.set_title("Count of Employees in different departments")
ac.set(xlabel="departments")
ac.set(ylabel="Count of employees")
# Out:
# [Text(0, 0.5, 'Count of employees')]

# %%
b = dataset['Department'].value_counts()
print(b)
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
# The Graph Of count of Attrition in IBM:
af=sb.countplot(data = dataset , x='Attrition')
af.set_title("The Graph of the count of Attrition in IBM")
af.set(xlabel="Attrition reponses")
af.set(ylabel="Attrition reponses count")
# Out:
# [Text(0, 0.5, 'Attrition reponses count')]

# %%
attrition_a= dataset['Attrition'].value_counts()
print(attrition_a)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
attrition= dataset['Attrition'].value_counts(normalize=True)
aa = attrition* 100
print(aa)
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
ad = sb.barplot(x=attrition.index, y=attrition)
ad.set_title("percentage of attrition")
ad.set(xlabel="attrition")
ad.set(ylabel="percentage")
# Out:
# [Text(0, 0.5, 'percentage')]

# %%
aa=sb.countplot(data = dataset , x='JobSatisfaction')
aa.set_title("Job Satisfaction Rating by Employees")
aa.set(xlabel="Rating of Job Satisfaction")
aa.set(ylabel="Count of rating 1 to 5")
# Out:
# [Text(0, 0.5, 'Count of rating 1 to 5')]

# %%
rating_of_job_sat=dataset['JobSatisfaction'].value_counts()
rating_of_job_sat
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
count_of_employees_by_edu=dataset['EducationField'].value_counts()
print(count_of_employees_by_edu)
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
af=sb.countplot(data = dataset , x='EducationField')
af.set_title("Graph Employees from different education background")
af.set(xlabel="Education")
af.set(ylabel="Count of rating employees")
# Out:
# [Text(0, 0.5, 'Count of rating employees')]

# %% [markdown]
# Final report of My Data Analysis:

# %% [markdown]
# Project Report: Basic details of the dataset consists of 1470 records. Total columns 35 columns. Total No. of rows 1470.Report of My Data Analysis: I Want to spilt the project report into Three parts: They are: Step 1 : Data collection, Data Loading And Data Cleaning.
# Step2: Data Analysis.
# Step3:Conculsion and Final statement.
# Step 1: Data collection, Data Loading And Data Cleaning. In this the Data collection in external from web in CSV file, The data loaded using the Pandas. The Data cleaning, In this part I have took a checks for missing values, duplicate values but In this file, there is no null values and duplicate values so, there is no need of Data cleaning for this case.

# %% [markdown]
# Step 2: Data Analysis:
# Insights drawn from the Data Analysis. From the Graph of the employees in the different Age groups. The Age range in between 30-40 Years age Employees are more, Who are working in the IBM.As per the graph of males VS females working IBM The Males Employees are more than the Female Employees. According to the Graph of employees in the different Departments in IBM The Highest employees working the Research And Development department, The next Highest employees working in Sales departments. As per the Graph of Attrition the Employees , The employees leaving the organization without proper reason are Low. From the Graph of the Job satisfaction the Top rating of the company is good The rating of the 4 is given by the 459 employees are given the rating of the 1 is given by 289 employees for the company.

# %% [markdown]
# 3.Conculsion and Final statement:
# From the above data analysis, the Age group employees working in the IBM seems to be Seniors So, It is Good have the Senior Employees in the company. As per the male employees are more the females with difference of just 294 not a big number, so it is okay. As per the employees in the Different departments, In this we must take care because the more no of employees should be the sales department. But there is no sufficient employees in the Sales department, so we need to hire more in sales department. About the Attrition it is low but still so numbers in Attrition so needed to take care. As per the Analysis the of job satisfaction rating it good but there still negative ratings so, it should be taken care.
